# %% [markdown]
# # CLAS Canine Longitudinal Aging Study
# ### Dec 1 2015, Seattle WA
#
# * Environ x Genetic predict healthy, morbidity, mortality... but age is hugely important. "black box" model.
# * Diagnosis, treatment, ... and citizen science
#
# Client info / RT sensor / electronic medical records (EMRs); OMics > data > biobank / vets / scientists / clients / public

# %% [markdown]
# Sean Mooney: CRIO UW Medicine: Dept Biomed Informatics and Medical Education
#
# UW Medicine = 4 hospitals. All EMR data aggregated.
#
# Vets use free text.
#
# Precision medicine involves voluntarily opening up as much of the inforation as possible.
#
# ### Owner Experience
#
# * Make your dog healthier from study feedback
# * Make yourself healthier by keeping your dog healthier
#
#
# ### Subscription
#
# ### Research Questions
#
# Factors that influence dog HMM:
#
# * Air quality
# * Food quality (processed; 'raw'; other considerations)
# * Water quality
# * Exposure in Infectious Disease Transmission risk > Longevity
# * Ambient sound/noise: Levels, spectrum, variability
# * Dog to human health correspondences
# * Exposure to outdoors / natural light / latitude patterns
# * Temperature, humidity
#
#
# ### Data Triage
#
# * Rob suggests papers on one axis, data on another; use a triage approach to place project resources.
#
# ### Classes of Data
#
# #### Dog
#
# ##### Animal
# ##### Metadata
# * RFID (GUID)
#     * Case where dog does not have an RFID tag
# * Datetime (time-zone rectified)
# * Location { reference (home), dog location per GPS }
#
# ##### Data
# * Acceleration / activity
# * Biometrics (temperature, heart rate, breathing, ...)
# * Weight
#
# #### Owner
# * Care history: Type/amount of food, water, walks, anomalies, ... (phone)
# * Metrics (measure weight, waistline, speed, ....)
#
# #### Environment
# * How 'walkable' is the neighborhood: 'Microbiome'
#
#
# Authentication for API use
#
# Owner annotations
#
# Biometric
#
# Ambient (non-dog) sensors
#
# Vet text
#
# Vet drop-downs
#
# Owner-vet-generated metadata: Diagnosis
#
# Medicine
#
# #### Not Dog
#
# Child
# Air particulates
# Radon
#
#
# ### Data Access Issues
#
# In flight analysis that shows that devices are not harming the dogs. This implies a view into dogs-not-in-the-study as an extension of dogs-in-the-study-who-do/do-not-have-sensor-X.
